# %%
import pandas as pd
df = pd.read_csv('all.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              449 non-null    float64
#  1   Date               455 non-null    object
#  2   Start Time         455 non-null    object
#  3   End Time           455 non-null    object
#  4   Course             455 non-null    object
#  5   Branch             455 non-null    object
#  6   Sem                455 non-null    object
#  7   Subject Name       455 non-null    object
#  8   Subject Code       455 non-null    object
#  9   Section            455 non-null    object
#  10  Group              455 non-null    object
#  11  Total students     455 non-null    int64
#  12  BLOCK              455 non-null    object
#  13  Lab No             455 non-null    object
#  14  Internal Examiner  455 non-null    object
#  15  External Examiner  454 non-null    object
# ...

# %%
df = df.iloc[:,[9,10,11,7,8,14]]
grouped = df.groupby("Section")

# %%
for key,item in grouped:
    internalTeacher = E
# Out:
#      Section Group  Total students                      Subject Name  \
# 421  20AML-1     A              38  ADVANCED DATABASE MANAGEMENT LAB
# 422  20AML-1     A              38                 DEEP LEARNING LAB
#
#     Subject Code
# 421    20CSP-436
# 422    20CSF-431
#      Section Group  Total students                      Subject Name  \
# 424  20AML-2     A              36                 DEEP LEARNING LAB
# 437  20AML-2     A              36  ADVANCED DATABASE MANAGEMENT LAB
#
#     Subject Code
# 424    20CSF-431
# 437    20CSP-436
#      Section Group  Total students                      Subject Name  \
# 383  20AML-3     A              36  ADVANCED DATABASE MANAGEMENT LAB
# 385  20AML-3     A              36                 DEEP LEARNING LAB
#
#     Subject Code
# 383    20CSP-436
# 385    20CSF-431
#      Section Group  Total students                      Subject Name  \
# 403  20AML-4     A              36  ADVANCED DATABASE MANAGEMENT LAB
# ...

# %%
group = ['A','B']
for year in range(20,23):
    for j in range(1,8):
        print(str(year)+"AML-"+str(j)+"/"+group[0])
        print(str(year)+"AML-"+str(j)+"/"+group[1])
# Out:
# 20AML-1/A
# 20AML-1/B
# 20AML-2/A
# 20AML-2/B
# 20AML-3/A
# 20AML-3/B
# 20AML-4/A
# 20AML-4/B
# 20AML-5/A
# 20AML-5/B
# 20AML-6/A
# 20AML-6/B
# 20AML-7/A
# 20AML-7/B
# 21AML-1/A
# 21AML-1/B
# 21AML-2/A
# 21AML-2/B
# 21AML-3/A
# 21AML-3/B
# 21AML-4/A
# 21AML-4/B
# 21AML-5/A
# 21AML-5/B
# 21AML-6/A
# 21AML-6/B
# 21AML-7/A
# 21AML-7/B
# 22AML-1/A
# 22AML-1/B
# 22AML-2/A
# 22AML-2/B
# 22AML-3/A
# 22AML-3/B
# 22AML-4/A
# 22AML-4/B
# 22AML-5/A
# 22AML-5/B
# 22AML-6/A
# 22AML-6/B
# 22AML-7/A
# 22AML-7/B
